# %% [markdown]
# # MEDDS: Face Spoof Detection Model

# %% [markdown]
# This notebook implements a Face Spoof Detection Model for the MEDDS (Multimodal Emotion and Distraction Detection System) capstone project. The model uses transfer learning with MobileNetV2 as a backbone to classify images as 'real' or 'spoof'.

# %% [markdown]
# ## 1. Environment Setup

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ## 2. Imports

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import os
import pickle
from PIL import Image # For image loading in inference

# %% [markdown]
# ## 3. Configuration

# %%
DATASET_BASE_PATH = 'DataSet_Spoof'
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 8 # Reduced batch size due to very small dataset (26 images)
NUM_CLASSES = 2
AUTOTUNE = tf.data.AUTOTUNE

# Model saving paths
MODEL_SAVE_PATH = 'spoof_model_v1.keras'
LABEL_ENCODER_PATH = 'label_encoder.pkl'

# Training parameters Stage 1
STAGE1_LEARNING_RATE = 1e-3
STAGE1_EPOCHS = 20

# Training parameters Stage 2 (Fine-tuning)
STAGE2_LEARNING_RATE = 1e-5
STAGE2_EPOCHS = 20

# %% [markdown]
# ## 4. Dataset Loading

# %%
def load_dataset(subset_name):
    dataset_path = os.path.join(DATASET_BASE_PATH, subset_name)
    print(f"Loading {subset_name} dataset from: {dataset_path}")
    dataset = image_dataset_from_directory(
        dataset_path,
        labels='inferred',
        label_mode='int',
        image_size=IMAGE_SIZE,
        interpolation='nearest',
        batch_size=BATCH_SIZE,
        shuffle=True if subset_name == 'train' else False # Only shuffle training data
    )
    return dataset

train_ds = load_dataset('train')
val_ds = load_dataset('val')
test_ds = load_dataset('test')

# Get class names and create a label encoder for saving
CLASS_NAMES = train_ds.class_names
class_to_idx = {cls_name: i for i, cls_name in enumerate(CLASS_NAMES)}
idx_to_class = {i: cls_name for i, cls_name in enumerate(CLASS_NAMES)}

print(f"\nDetected class names: {CLASS_NAMES}")
print(f"Class to index mapping: {class_to_idx}")

# Save label encoder
with open(LABEL_ENCODER_PATH, 'wb') as f:
    pickle.dump(idx_to_class, f)
print(f"Label encoder saved to {LABEL_ENCODER_PATH}")
# Out:
# Loading train dataset from: DataSet_Spoof\train
# Found 8190 files belonging to 2 classes.
# Loading val dataset from: DataSet_Spoof\val
# Found 911 files belonging to 2 classes.
# Loading test dataset from: DataSet_Spoof\test
# Found 2276 files belonging to 2 classes.
#
# Detected class names: ['real', 'spoof']
# Class to index mapping: {'real': 0, 'spoof': 1}
# Label encoder saved to label_encoder.pkl

# %% [markdown]
# ## 5. Dataset Analysis

# %%
def count_images_in_dataset(dataset):
    count = 0
    class_counts = {name: 0 for name in CLASS_NAMES}
    for images, labels in dataset:
        count += images.shape[0]
        for label in labels.numpy():
            class_counts[CLASS_NAMES[label]] += 1
    return count, class_counts

print("\n--- Dataset Counts ---")
train_count, train_class_counts = count_images_in_dataset(train_ds)
val_count, val_class_counts = count_images_in_dataset(val_ds)
test_count, test_class_counts = count_images_in_dataset(test_ds)

print(f"Train images: {train_count}, Class counts: {train_class_counts}")
print(f"Validation images: {val_count}, Class counts: {val_class_counts}")
print(f"Test images: {test_count}, Class counts: {test_class_counts}")

# Display a batch of images (dynamically adjusted for batch size)
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    num_to_display = min(len(images), 9) # Prevent index error if batch < 9
    for i in range(num_to_display):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(CLASS_NAMES[labels[i]])
        plt.axis("off")
plt.suptitle("Sample Training Images")
plt.show()
# Out:
# --- Dataset Counts ---
# Train images: 8190, Class counts: {'real': 3676, 'spoof': 4514}
# Validation images: 911, Class counts: {'real': 409, 'spoof': 502}
# Test images: 2276, Class counts: {'real': 1021, 'spoof': 1255}

# %% [markdown]
# ## 6. Data Augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
        layers.RandomZoom(0.2),
        layers.RandomContrast(0.2),
    ],
    name="data_augmentation",
)

# %% [markdown]
# ## 7. Dataset Pipelines

# %%
def preprocess_data(image, label):
    # Cast to float32 to match MobileNetV2 preprocessing requirements
    image = tf.cast(image, tf.float32)
    # Apply MobileNetV2 specific preprocessing (scaling pixels to [-1, 1])
    image = preprocess_input(image)
    return image, label

def augment_and_preprocess(image, label):
    # Apply augmentation only to training data
    image = data_augmentation(image, training=True)
    # Cast to float32 to match MobileNetV2 preprocessing requirements
    image = tf.cast(image, tf.float32)
    # Apply MobileNetV2 specific preprocessing
    image = preprocess_input(image)
    return image, label

# Fix: Use the actual number of training samples for the shuffle buffer
shuffle_buffer = train_count if train_count > 0 else 100

train_ds_processed = train_ds.map(augment_and_preprocess, num_parallel_calls=AUTOTUNE).cache().shuffle(shuffle_buffer).prefetch(AUTOTUNE)
val_ds_processed = val_ds.map(preprocess_data, num_parallel_calls=AUTOTUNE).cache().prefetch(AUTOTUNE)
test_ds_processed = test_ds.map(preprocess_data, num_parallel_calls=AUTOTUNE).cache().prefetch(AUTOTUNE)

print(f"Dataset pipelines configured with shuffle buffer: {shuffle_buffer}")
# Out:
# Dataset pipelines configured with shuffle buffer: 8190

# %% [markdown]
# ## 8. Class Weights

# %%
# Extract all labels from the training dataset to compute class weights
all_train_labels = []
for _, labels in train_ds:
    all_train_labels.extend(labels.numpy())

# Compute class weights
class_weights_array = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(all_train_labels),
    y=all_train_labels
)
class_weights = {i: weight for i, weight in enumerate(class_weights_array)}

print(f"Computed class weights: {class_weights}")
# Out:
# Computed class weights: {0: 1.1139825897714908, 1: 0.9071776694727515}

# %% [markdown]
# ## 9. Model Construction

# %%
def build_model(num_classes):
    # Load MobileNetV2 backbone, pretrained on ImageNet
    base_model = MobileNetV2(
        input_shape=IMAGE_SIZE + (3,),
        include_top=False,
        weights='imagenet'
    )

    # Stage 1: Freeze the backbone
    base_model.trainable = False

    # Create the classifier head
    inputs = keras.Input(shape=IMAGE_SIZE + (3,))
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = keras.Model(inputs, outputs)
    return model

model = build_model(NUM_CLASSES)
model.summary()
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# ## 10. Training (Stage 1: Train Classifier Head)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=STAGE1_LEARNING_RATE),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# Callbacks for Stage 1
callbacks_stage1 = [
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_accuracy', factor=0.2, patience=3, min_lr=1e-6, verbose=1),
    ModelCheckpoint(filepath='stage1_best_model.keras', monitor='val_accuracy', save_best_only=True, verbose=1)
]

# Explicitly ensuring datasets are available in this scope
print(f"\nStarting Stage 1 Training (Classifier Head) for {STAGE1_EPOCHS} epochs...")
history_stage1 = model.fit(
    train_ds_processed,
    epochs=STAGE1_EPOCHS,
    validation_data=val_ds_processed,
    class_weight=class_weights,
    callbacks=callbacks_stage1
)

print("Stage 1 Training Complete.")
# Out:
# Starting Stage 1 Training (Classifier Head) for 20 epochs...
# Epoch 1/20
# 1023/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7884 - loss: 0.4694
# Epoch 1: val_accuracy improved from None to 0.87706, saving model to stage1_best_model.keras
#
# Epoch 1: finished saving model to stage1_best_model.keras
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 54s 44ms/step - accuracy: 0.8315 - loss: 0.3818 - val_accuracy: 0.8771 - val_loss: 0.2799 - learning_rate: 0.0010
# Epoch 2/20
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9021 - loss: 0.2349
# Epoch 2: val_accuracy improved from 0.87706 to 0.90999, saving model to stage1_best_model.keras
#
# Epoch 2: finished saving model to stage1_best_model.keras
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 47s 46ms/step - accuracy: 0.9035 - loss: 0.2315 - val_accuracy: 0.9100 - val_loss: 0.2034 - learning_rate: 0.0010
# Epoch 3/20
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9259 - loss: 0.1795
# ...

# %% [markdown]
# ## 11. Fine Tuning (Stage 2: Unfreeze Upper MobileNetV2 Layers)

# %%
import os
# Use absolute path to ensure the model is found
stage1_path = os.path.abspath('stage1_best_model.keras')

if os.path.exists(stage1_path):
    model = keras.models.load_model(stage1_path)
    print(f"Successfully loaded Stage 1 model from {stage1_path}")

    # Unfreeze the MobileNetV2 backbone
    base_model = model.layers[1] # MobileNetV2 is typically the second layer in this functional setup
    base_model.trainable = True

    # Freeze all but the last 40 layers
    for layer in base_model.layers[:-40]:
        layer.trainable = False

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=STAGE2_LEARNING_RATE),
        loss=keras.losses.SparseCategoricalCrossentropy(),
        metrics=['accuracy']
    )

    callbacks_stage2 = [
        EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1),
        ReduceLROnPlateau(monitor='val_accuracy', factor=0.2, patience=5, min_lr=1e-7, verbose=1),
        ModelCheckpoint(filepath=os.path.abspath(MODEL_SAVE_PATH), monitor='val_accuracy', save_best_only=True, verbose=1)
    ]

    print(f"\nStarting Stage 2 Fine-tuning...")
    history_stage2 = model.fit(
        train_ds_processed,
        epochs=STAGE2_EPOCHS,
        validation_data=val_ds_processed,
        class_weight=class_weights,
        callbacks=callbacks_stage2
    )
else:
    print(f"Error: {stage1_path} not found. Please run the Stage 1 training cell again.")
# Out:
# Successfully loaded Stage 1 model from d:\AI\MEDDS\Spoof_Model\stage1_best_model.keras
#
# Starting Stage 2 Fine-tuning...
# Epoch 1/20
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8889 - loss: 0.3127
# Epoch 1: val_accuracy improved from None to 0.93524, saving model to d:\AI\MEDDS\Spoof_Model\spoof_model_v1.keras
#
# Epoch 1: finished saving model to d:\AI\MEDDS\Spoof_Model\spoof_model_v1.keras
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 85s 76ms/step - accuracy: 0.9015 - loss: 0.2634 - val_accuracy: 0.9352 - val_loss: 0.1736 - learning_rate: 1.0000e-05
# Epoch 2/20
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9547 - loss: 0.1186
# Epoch 2: val_accuracy did not improve from 0.93524
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 99s 97ms/step - accuracy: 0.9597 - loss: 0.1062 - val_accuracy: 0.9177 - val_loss: 0.2014 - learning_rate: 1.0000e-05
# Epoch 3/20
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9798 - loss: 0.0619
# ...

# %% [markdown]
# ## 12. Evaluation

# %%
final_model_path = os.path.abspath(MODEL_SAVE_PATH)
if os.path.exists(final_model_path):
    final_model = keras.models.load_model(final_model_path)
    print("\n--- Evaluating Final Model on Test Set ---")
    loss, accuracy = final_model.evaluate(test_ds_processed)
    print(f"Test Loss: {loss:.4f}")
    print(f"Test Accuracy: {accuracy:.4f}")
    # plot_training_history call remains here...
else:
    print(f"Error: Final model file {final_model_path} not found. Complete Stage 2 first.")
# Out:
# --- Evaluating Final Model on Test Set ---
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 17s 52ms/step - accuracy: 0.9214 - loss: 0.1906
# Test Loss: 0.1906
# Test Accuracy: 0.9214

# %% [markdown]
# ## 13. Confusion Matrix

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

print("\n--- Generating Confusion Matrix ---")

# Ensure model is loaded using absolute path
final_model_path = os.path.abspath(MODEL_SAVE_PATH)
if os.path.exists(final_model_path):
    eval_model = keras.models.load_model(final_model_path)

    # Get true labels and predicted labels for the test set
    # Re-extracting from test_ds_processed to ensure consistency
    true_labels = []
    for _, labels in test_ds_processed:
        true_labels.extend(labels.numpy())
    true_labels = np.array(true_labels)

    predictions = eval_model.predict(test_ds_processed)
    predicted_labels = np.argmax(predictions, axis=1)

    # Create confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()
else:
    print(f"Model file not found at {final_model_path}")
# Out:
# --- Generating Confusion Matrix ---
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 16s 55ms/step

# %% [markdown]
# ## 14. Classification Report

# %%
from sklearn.metrics import classification_report

print("\n--- Generating Classification Report ---")

# Ensure variables exist from the previous cell or recalculate
if 'predicted_labels' not in locals() and 'predicted_labels' not in globals():
    final_model_path = os.path.abspath(MODEL_SAVE_PATH)
    eval_model = keras.models.load_model(final_model_path)

    true_labels = []
    for _, labels in test_ds_processed:
        true_labels.extend(labels.numpy())
    true_labels = np.array(true_labels)

    predictions = eval_model.predict(test_ds_processed)
    predicted_labels = np.argmax(predictions, axis=1)

print(classification_report(true_labels, predicted_labels, target_names=CLASS_NAMES))
# Out:
# --- Generating Classification Report ---
#               precision    recall  f1-score   support
#
#         real       0.92      0.91      0.91      1021
#        spoof       0.93      0.93      0.93      1255
#
#     accuracy                           0.92      2276
#    macro avg       0.92      0.92      0.92      2276
# weighted avg       0.92      0.92      0.92      2276

# %% [markdown]
# ## 15. Model Saving

# %%
# Model was already saved by ModelCheckpoint during Stage 2 training
print(f"Final model saved to {MODEL_SAVE_PATH}")
print(f"Label encoder saved to {LABEL_ENCODER_PATH}")
# Out:
# Final model saved to spoof_model_v1.keras
# Label encoder saved to label_encoder.pkl

# %% [markdown]
# ## 16. Inference Example

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow import keras
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

print("\n--- Running Inference Example ---")

# Use absolute path to avoid file not found errors
final_model_path = os.path.abspath(MODEL_SAVE_PATH)

if os.path.exists(final_model_path):
    # Load the saved model
    inference_model = keras.models.load_model(final_model_path)

    # Load the label encoder
    with open(LABEL_ENCODER_PATH, 'rb') as f:
        loaded_idx_to_class = pickle.load(f)

    def load_and_preprocess_image_for_inference(image_path, target_size=IMAGE_SIZE):
        img = Image.open(image_path).convert('RGB')
        img = img.resize(target_size)
        img_array = np.array(img)
        img_array = np.expand_dims(img_array, axis=0) # Add batch dimension
        img_array = img_array.astype('float32')
        img_array = preprocess_input(img_array) # Apply MobileNetV2 preprocessing
        return img_array, img

    # Function to get a random image path from the test set
    def get_random_test_image_path(dataset_base_path=DATASET_BASE_PATH, subset_name='test'):
        test_dir = os.path.join(dataset_base_path, subset_name)
        classes = [d for d in os.listdir(test_dir) if os.path.isdir(os.path.join(test_dir, d))]
        random_class = np.random.choice(classes)
        class_path = os.path.join(test_dir, random_class)
        images = [f for f in os.listdir(class_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
        random_image = np.random.choice(images)
        return os.path.join(class_path, random_image)

    # Get a sample image from the test set
    sample_image_path = get_random_test_image_path()
    processed_image_array, original_image = load_and_preprocess_image_for_inference(sample_image_path)

    # Predict probabilities
    probabilities = inference_model.predict(processed_image_array)[0]
    predicted_class_idx = np.argmax(probabilities)
    predicted_class_name = loaded_idx_to_class[predicted_class_idx]

    # Display results
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title(f"Original Image\nActual: {os.path.basename(os.path.dirname(sample_image_path))}")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    class_labels = list(loaded_idx_to_class.values())
    plt.bar(class_labels, probabilities, color=['skyblue', 'lightcoral'])
    plt.ylabel('Probability')
    plt.title('Prediction Probabilities')
    plt.ylim(0, 1)

    for i, prob in enumerate(probabilities):
        plt.text(i, prob + 0.02, f'{prob:.2f}', ha='center', va='bottom', fontsize=10)

    plt.tight_layout()
    plt.show()

    print(f"Predicted Probabilities: {{\"real\": {probabilities[class_to_idx['real']]:.2f}, \"spoof\": {probabilities[class_to_idx['spoof']]:.2f}}}")
    print(f"Predicted Class: {predicted_class_name}")
else:
    print(f"Error: Model file not found at {final_model_path}")
# Out:
# --- Running Inference Example ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# Predicted Probabilities: {"real": 0.95, "spoof": 0.05}
# Predicted Class: real
